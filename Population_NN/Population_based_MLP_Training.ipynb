# %% [markdown]
# <a href="https://colab.research.google.com/github/nikalitt1/Clementine-Agriculture/blob/main/Population_based_MLP_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import Omniglot
import torchvision.transforms as transforms
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import accuracy_score
import random

# ====== Setup ======
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# ====== Load Omniglot Dataset ======
transform = transforms.Compose([
    transforms.Resize((28, 28)),  # Resize images to 28x28
    transforms.ToTensor(),        # Convert PIL image to tensor scaled [0,1]
])

train_dataset = Omniglot(root='./data', background=True, download=True, transform=transform)
test_dataset = Omniglot(root='./data', background=False, download=True, transform=transform)

full_data = train_dataset + test_dataset

# Extract data and labels into numpy arrays
X = []
y = []
for img, label in full_data:
    X.append(img.view(-1).numpy())  # flatten 28x28 -> 784 vector
    y.append(label)

X = np.stack(X)
y = np.array(y)

max_classes = 50
mask = y < max_classes
X = X[mask]
y = y[mask]

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Train/val/test split: 70/15/15 stratified
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y_encoded, test_size=0.15, random_state=42, stratify=y_encoded)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.1765, random_state=42, stratify=y_trainval)

# Convert to tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.long)
X_val_t = torch.tensor(X_val, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.long)
X_test_t = torch.tensor(X_test, dtype=torch.float32)
y_test_t = torch.tensor(y_test, dtype=torch.long)

batch_size = 64
train_loader = DataLoader(torch.utils.data.TensorDataset(X_train_t, y_train_t), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(torch.utils.data.TensorDataset(X_val_t, y_val_t), batch_size=batch_size)
test_loader = DataLoader(torch.utils.data.TensorDataset(X_test_t, y_test_t), batch_size=batch_size)

# ====== Define MLP Model ======
class OmniglotMLP(nn.Module):
    def __init__(self, input_size=28*28, num_classes=max_classes):
        super(OmniglotMLP, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# ====== Evaluation function ======
def evaluate_model(model, dataloader):
    model.eval()
    all_preds = []
    all_targets = []
    with torch.no_grad():
        for xb, yb in dataloader:
            xb, yb = xb.to(device), yb.to(device)
            xb = xb.view(xb.size(0), -1)  # Flatten
            logits = model(xb)
            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu().numpy())
            all_targets.append(yb.cpu().numpy())
    all_preds = np.concatenate(all_preds)
    all_targets = np.concatenate(all_targets)
    return accuracy_score(all_targets, all_preds)

# ====== Training function for one epoch ======
def train_one_epoch(model, optimizer, criterion, dataloader, model_id=None, epoch_num=None, log_every=100):
    model.train()
    running_loss = 0.0
    for batch_idx, (xb, yb) in enumerate(dataloader, 1):
        xb, yb = xb.to(device), yb.to(device)
        xb = xb.view(xb.size(0), -1)  # Flatten
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if batch_idx % log_every == 0:
            avg_loss = running_loss / log_every
            running_loss = 0.0
            prefix = f"Model {model_id} - Epoch {epoch_num}" if model_id is not None and epoch_num is not None else ""
            print(f"{prefix} - Batch {batch_idx}/{len(dataloader)} - Loss: {avg_loss:.4f}")

# ====== Evolutionary Training with Elitism ======
def evolution_training_until_one(
    population_size=10,
    survival_rate=0.6,
    epochs_per_gen=10,
    log_every_batches=100
):
    population = []
    optimizers = []
    criterion = nn.CrossEntropyLoss()

    # Initialize population and optimizers
    for _ in range(population_size):
        model = OmniglotMLP().to(device)
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        population.append(model)
        optimizers.append(optimizer)

    generation = 0
    best_model = None
    best_optimizer = None
    best_score = -float('inf')

    while len(population) > 1:
        generation += 1
        print(f"\n🌱 Generation {generation} | Population size: {len(population)}")

        # Train all models in population
        for i, (model, optimizer) in enumerate(zip(population, optimizers)):
            print(f"  - Training model {i+1}/{len(population)}")
            for epoch in range(1, epochs_per_gen + 1):
                train_one_epoch(model, optimizer, criterion, train_loader, model_id=i+1, epoch_num=epoch, log_every=log_every_batches)

        # Evaluate all models
        scores = [evaluate_model(m, val_loader) for m in population]
        sorted_indices = np.argsort(scores)[::-1]  # Descending order

        # Update best model (elitism)
        if scores[sorted_indices[0]] > best_score:
            best_score = scores[sorted_indices[0]]
            best_model = population[sorted_indices[0]]
            best_optimizer = optimizers[sorted_indices[0]]
            print(f"  🎉 New best model with accuracy: {best_score:.4f}")

        # Survival selection
        survivors = max(1, int(len(population) * survival_rate))
        population = [population[i] for i in sorted_indices[:survivors]]
        optimizers = [optimizers[i] for i in sorted_indices[:survivors]]

        # Add best model back if lost (elitism)
        if best_model not in population:
            population.append(best_model)
            optimizers.append(best_optimizer)
            print("  🔄 Best model preserved with elitism")

        print(f"  ✅ Best Acc This Gen: {scores[sorted_indices[0]]:.4f} | Worst: {scores[sorted_indices[-1]]:.4f}")

    # Save best model
    torch.save(best_model.state_dict(), "best_omniglot_model.pth")
    return best_model

# ====== Run Evolution Training ======
best_model = evolution_training_until_one(
    population_size=1000,    # You can adjust this as needed
    survival_rate=0.6,
    epochs_per_gen=10,
    log_every_batches=100
)

# ====== Final Evaluation ======
best_model.eval()
test_accuracy = evaluate_model(best_model, test_loader)
print(f"\n🎯 Final test accuracy on Omniglot: {test_accuracy * 100:.2f}%")
# Out:
# 🌱 Generation 1 | Population size: 1000
#   - Training model 1/1000
#   - Training model 2/1000
#   - Training model 3/1000
#   - Training model 4/1000
#   - Training model 5/1000
#   - Training model 6/1000
#   - Training model 7/1000
#   - Training model 8/1000
#   - Training model 9/1000
#   - Training model 10/1000
#   - Training model 11/1000
#   - Training model 12/1000
#   - Training model 13/1000
#   - Training model 14/1000
#   - Training model 15/1000
#   - Training model 16/1000
#   - Training model 17/1000
#   - Training model 18/1000
#   - Training model 19/1000
#   - Training model 20/1000
#   - Training model 21/1000
#   - Training model 22/1000
#   - Training model 23/1000
#   - Training model 24/1000
#   - Training model 25/1000
#   - Training model 26/1000
#   - Training model 27/1000
#   - Training model 28/1000
#   - Training model 29/1000
#   - Training model 30/1000
#   - Training model 31/1000
#   - Training model 32/1000
#   - Training model 33/1000
#   - Training model 34/1000
#   - Training model 35/1000
#   - Training model 36/1000
#   - Training model 37/1000
#   - Training model 38/1000
#   - Training model 39/1000
#   - Training model 40/1000
#   - Training model 41/1000
#   - Training model 42/1000
#   - Training model 43/1000
#   - Training model 44/1000
#   - Training model 45/1000
#   - Training model 46/1000
#   - Training model 47/1000
#   - Training model 48/1000
#   - Training model 49/1000
#   - Training model 50/1000
#   - Training model 51/1000
#   - Training model 52/1000
#   - Training model 53/1000
#   - Training model 54/1000
#   - Training model 55/1000
#   - Training model 56/1000
#   - Training model 57/1000
#   - Training model 58/1000
#   - Training model 59/1000
#   - Training model 60/1000
#   - Training model 61/1000
#   - Training model 62/1000
#   - Training model 63/1000
#   - Training model 64/1000
#   - Training model 65/1000
#   - Training model 66/1000
#   - Training model 67/1000
#   - Training model 68/1000
#   - Training model 69/1000
#   - Training model 70/1000
#   - Training model 71/1000
#   - Training model 72/1000
#   - Training model 73/1000
#   - Training model 74/1000
#   - Training model 75/1000
#   - Training model 76/1000
#   - Training model 77/1000
#   - Training model 78/1000
#   - Training model 79/1000
#   - Training model 80/1000
#   - Training model 81/1000
#   - Training model 82/1000
#   - Training model 83/1000
#   - Training model 84/1000
#   - Training model 85/1000
#   - Training model 86/1000
#   - Training model 87/1000
#   - Training model 88/1000
#   - Training model 89/1000
#   - Training model 90/1000
#   - Training model 91/1000
#   - Training model 92/1000
#   - Training model 93/1000
#   - Training model 94/1000
#   - Training model 95/1000
#   - Training model 96/1000
#   - Training model 97/1000
#   - Training model 98/1000
#   - Training model 99/1000
#   - Training model 100/1000
#   - Training model 101/1000
#   - Training model 102/1000
#   - Training model 103/1000
#   - Training model 104/1000
#   - Training model 105/1000
#   - Training model 106/1000
#   - Training model 107/1000
#   - Training model 108/1000
#   - Training model 109/1000
#   - Training model 110/1000
#   - Training model 111/1000
#   - Training model 112/1000
#   - Training model 113/1000
#   - Training model 114/1000
#   - Training model 115/1000
#   - Training model 116/1000
#   - Training model 117/1000
#   - Training model 118/1000
#   - Training model 119/1000
#   - Training model 120/1000
#   - Training model 121/1000
#   - Training model 122/1000
#   - Training model 123/1000
#   - Training model 124/1000
#   - Training model 125/1000
#   - Training model 126/1000
#   - Training model 127/1000
#   - Training model 128/1000
#   - Training model 129/1000
#   - Training model 130/1000
#   - Training model 131/1000
#   - Training model 132/1000
#   - Training model 133/1000
#   - Training model 134/1000
#   - Training model 135/1000
#   - Training model 136/1000
#   - Training model 137/1000
#   - Training model 138/1000
#   - Training model 139/1000
#   - Training model 140/1000
#   - Training model 141/1000
#   - Training model 142/1000
#   - Training model 143/1000
#   - Training model 144/1000
#   - Training model 145/1000
#   - Training model 146/1000
#   - Training model 147/1000
#   - Training model 148/1000
#   - Training model 149/1000
#   - Training model 150/1000
#   - Training model 151/1000
#   - Training model 152/1000
#   - Training model 153/1000
#   - Training model 154/1000
#   - Training model 155/1000
#   - Training model 156/1000
#   - Training model 157/1000
#   - Training model 158/1000
#   - Training model 159/1000
#   - Training model 160/1000
#   - Training model 161/1000
#   - Training model 162/1000
#   - Training model 163/1000
#   - Training model 164/1000
#   - Training model 165/1000
#   - Training model 166/1000
#   - Training model 167/1000
#   - Training model 168/1000
#   - Training model 169/1000
#   - Training model 170/1000
#   - Training model 171/1000
#   - Training model 172/1000
#   - Training model 173/1000
#   - Training model 174/1000
#   - Training model 175/1000
#   - Training model 176/1000
#   - Training model 177/1000
#   - Training model 178/1000
#   - Training model 179/1000
#   - Training model 180/1000
#   - Training model 181/1000
#   - Training model 182/1000
#   - Training model 183/1000
#   - Training model 184/1000
#   - Training model 185/1000
#   - Training model 186/1000
#   - Training model 187/1000
#   - Training model 188/1000
#   - Training model 189/1000
#   - Training model 190/1000
#   - Training model 191/1000
#   - Training model 192/1000
#   - Training model 193/1000
#   - Training model 194/1000
#   - Training model 195/1000
#   - Training model 196/1000
#   - Training model 197/1000
#   - Training model 198/1000
#   - Training model 199/1000
#   - Training model 200/1000
#   - Training model 201/1000
#   - Training model 202/1000
#   - Training model 203/1000
#   - Training model 204/1000
#   - Training model 205/1000
#   - Training model 206/1000
#   - Training model 207/1000
#   - Training model 208/1000
#   - Training model 209/1000
#   - Training model 210/1000
#   - Training model 211/1000
#   - Training model 212/1000
#   - Training model 213/1000
#   - Training model 214/1000
#   - Training model 215/1000
#   - Training model 216/1000
#   - Training model 217/1000
#   - Training model 218/1000
#   - Training model 219/1000
#   - Training model 220/1000
#   - Training model 221/1000
#   - Training model 222/1000
#   - Training model 223/1000
#   - Training model 224/1000
#   - Training model 225/1000
#   - Training model 226/1000
#   - Training model 227/1000
#   - Training model 228/1000
#   - Training model 229/1000
#   - Training model 230/1000
#   - Training model 231/1000
#   - Training model 232/1000
#   - Training model 233/1000
#   - Training model 234/1000
#   - Training model 235/1000
#   - Training model 236/1000
#   - Training model 237/1000
#   - Training model 238/1000
#   - Training model 239/1000
#   - Training model 240/1000
#   - Training model 241/1000
#   - Training model 242/1000
#   - Training model 243/1000
#   - Training model 244/1000
#   - Training model 245/1000
#   - Training model 246/1000
#   - Training model 247/1000
#   - Training model 248/1000
#   - Training model 249/1000
#   - Training model 250/1000
#   - Training model 251/1000
#   - Training model 252/1000
#   - Training model 253/1000
#   - Training model 254/1000
#   - Training model 255/1000
#   - Training model 256/1000
#   - Training model 257/1000
#   - Training model 258/1000
#   - Training model 259/1000
#   - Training model 260/1000
#   - Training model 261/1000
#   - Training model 262/1000
#   - Training model 263/1000
#   - Training model 264/1000
#   - Training model 265/1000
#   - Training model 266/1000
#   - Training model 267/1000
#   - Training model 268/1000
#   - Training model 269/1000
#   - Training model 270/1000
#   - Training model 271/1000
#   - Training model 272/1000
#   - Training model 273/1000
#   - Training model 274/1000
#   - Training model 275/1000
#   - Training model 276/1000
#   - Training model 277/1000
#   - Training model 278/1000
#   - Training model 279/1000
#   - Training model 280/1000
#   - Training model 281/1000
#   - Training model 282/1000
#   - Training model 283/1000
#   - Training model 284/1000
#   - Training model 285/1000
#   - Training model 286/1000
#   - Training model 287/1000
#   - Training model 288/1000
#   - Training model 289/1000
#   - Training model 290/1000
#   - Training model 291/1000
#   - Training model 292/1000
#   - Training model 293/1000
#   - Training model 294/1000
#   - Training model 295/1000
#   - Training model 296/1000
#   - Training model 297/1000
#   - Training model 298/1000
#   - Training model 299/1000
#   - Training model 300/1000
#   - Training model 301/1000
#   - Training model 302/1000
#   - Training model 303/1000
#   - Training model 304/1000
#   - Training model 305/1000
#   - Training model 306/1000
#   - Training model 307/1000
#   - Training model 308/1000
#   - Training model 309/1000
#   - Training model 310/1000
#   - Training model 311/1000
#   - Training model 312/1000
#   - Training model 313/1000
#   - Training model 314/1000
#   - Training model 315/1000
#   - Training model 316/1000
#   - Training model 317/1000
#   - Training model 318/1000
#   - Training model 319/1000
#   - Training model 320/1000
#   - Training model 321/1000
#   - Training model 322/1000
#   - Training model 323/1000
#   - Training model 324/1000
#   - Training model 325/1000
#   - Training model 326/1000
#   - Training model 327/1000
#   - Training model 328/1000
#   - Training model 329/1000
#   - Training model 330/1000
#   - Training model 331/1000
#   - Training model 332/1000
#   - Training model 333/1000
#   - Training model 334/1000
#   - Training model 335/1000
#   - Training model 336/1000
#   - Training model 337/1000
#   - Training model 338/1000
#   - Training model 339/1000
#   - Training model 340/1000
#   - Training model 341/1000
#   - Training model 342/1000
#   - Training model 343/1000
#   - Training model 344/1000
#   - Training model 345/1000
#   - Training model 346/1000
#   - Training model 347/1000
#   - Training model 348/1000
#   - Training model 349/1000
#   - Training model 350/1000
#   - Training model 351/1000
#   - Training model 352/1000
#   - Training model 353/1000
#   - Training model 354/1000
#   - Training model 355/1000
#   - Training model 356/1000
#   - Training model 357/1000
#   - Training model 358/1000
#   - Training model 359/1000
#   - Training model 360/1000
#   - Training model 361/1000
#   - Training model 362/1000
#   - Training model 363/1000
#   - Training model 364/1000
#   - Training model 365/1000
#   - Training model 366/1000
#   - Training model 367/1000
#   - Training model 368/1000
#   - Training model 369/1000
#   - Training model 370/1000
#   - Training model 371/1000
#   - Training model 372/1000
#   - Training model 373/1000
#   - Training model 374/1000
#   - Training model 375/1000
#   - Training model 376/1000
#   - Training model 377/1000
#   - Training model 378/1000
#   - Training model 379/1000
#   - Training model 380/1000
#   - Training model 381/1000
#   - Training model 382/1000
#   - Training model 383/1000
#   - Training model 384/1000
#   - Training model 385/1000
#   - Training model 386/1000
#   - Training model 387/1000
#   - Training model 388/1000
#   - Training model 389/1000
#   - Training model 390/1000
#   - Training model 391/1000
#   - Training model 392/1000
#   - Training model 393/1000
#   - Training model 394/1000
#   - Training model 395/1000
#   - Training model 396/1000
#   - Training model 397/1000
#   - Training model 398/1000
#   - Training model 399/1000
#   - Training model 400/1000
#   - Training model 401/1000
#   - Training model 402/1000
#   - Training model 403/1000
#   - Training model 404/1000
#   - Training model 405/1000
#   - Training model 406/1000
#   - Training model 407/1000
#   - Training model 408/1000
#   - Training model 409/1000
#   - Training model 410/1000
#   - Training model 411/1000
#   - Training model 412/1000
#   - Training model 413/1000
#   - Training model 414/1000
#   - Training model 415/1000
#   - Training model 416/1000
#   - Training model 417/1000
#   - Training model 418/1000
#   - Training model 419/1000
#   - Training model 420/1000
#   - Training model 421/1000
#   - Training model 422/1000
#   - Training model 423/1000
#   - Training model 424/1000
#   - Training model 425/1000
#   - Training model 426/1000
#   - Training model 427/1000
#   - Training model 428/1000
#   - Training model 429/1000
#   - Training model 430/1000
#   - Training model 431/1000
#   - Training model 432/1000
#   - Training model 433/1000
#   - Training model 434/1000
#   - Training model 435/1000
#   - Training model 436/1000
#   - Training model 437/1000
#   - Training model 438/1000
#   - Training model 439/1000
#   - Training model 440/1000
#   - Training model 441/1000
#   - Training model 442/1000
#   - Training model 443/1000
#   - Training model 444/1000
#   - Training model 445/1000
#   - Training model 446/1000
#   - Training model 447/1000
#   - Training model 448/1000
#   - Training model 449/1000
#   - Training model 450/1000
#   - Training model 451/1000
#   - Training model 452/1000
#   - Training model 453/1000
#   - Training model 454/1000
#   - Training model 455/1000
#   - Training model 456/1000
#   - Training model 457/1000
#   - Training model 458/1000
#   - Training model 459/1000
#   - Training model 460/1000
#   - Training model 461/1000
#   - Training model 462/1000
#   - Training model 463/1000
#   - Training model 464/1000
#   - Training model 465/1000
#   - Training model 466/1000
#   - Training model 467/1000
#   - Training model 468/1000
#   - Training model 469/1000
#   - Training model 470/1000
#   - Training model 471/1000
#   - Training model 472/1000
#   - Training model 473/1000
#   - Training model 474/1000
#   - Training model 475/1000
#   - Training model 476/1000
#   - Training model 477/1000
#   - Training model 478/1000
#   - Training model 479/1000
#   - Training model 480/1000
#   - Training model 481/1000
#   - Training model 482/1000
#   - Training model 483/1000
#   - Training model 484/1000
#   - Training model 485/1000
#   - Training model 486/1000
#   - Training model 487/1000
#   - Training model 488/1000
#   - Training model 489/1000
#   - Training model 490/1000
#   - Training model 491/1000
#   - Training model 492/1000
#   - Training model 493/1000
#   - Training model 494/1000
#   - Training model 495/1000
#   - Training model 496/1000
#   - Training model 497/1000
#   - Training model 498/1000
#   - Training model 499/1000
#   - Training model 500/1000
#   - Training model 501/1000
#   - Training model 502/1000
#   - Training model 503/1000
#   - Training model 504/1000
#   - Training model 505/1000
#   - Training model 506/1000
#   - Training model 507/1000
#   - Training model 508/1000
#   - Training model 509/1000
#   - Training model 510/1000
#   - Training model 511/1000
#   - Training model 512/1000
#   - Training model 513/1000
#   - Training model 514/1000
#   - Training model 515/1000
#   - Training model 516/1000
#   - Training model 517/1000
#   - Training model 518/1000
#   - Training model 519/1000
#   - Training model 520/1000
#   - Training model 521/1000
#   - Training model 522/1000
#   - Training model 523/1000
#   - Training model 524/1000
#   - Training model 525/1000
#   - Training model 526/1000
#   - Training model 527/1000
#   - Training model 528/1000
#   - Training model 529/1000
#   - Training model 530/1000
#   - Training model 531/1000
#   - Training model 532/1000
#   - Training model 533/1000
#   - Training model 534/1000
#   - Training model 535/1000
#   - Training model 536/1000
#   - Training model 537/1000
#   - Training model 538/1000
#   - Training model 539/1000
#   - Training model 540/1000
#   - Training model 541/1000
#   - Training model 542/1000
#   - Training model 543/1000
#   - Training model 544/1000
#   - Training model 545/1000
#   - Training model 546/1000
#   - Training model 547/1000
#   - Training model 548/1000
#   - Training model 549/1000
#   - Training model 550/1000
#   - Training model 551/1000
#   - Training model 552/1000
#   - Training model 553/1000
#   - Training model 554/1000
#   - Training model 555/1000
#   - Training model 556/1000
#   - Training model 557/1000
#   - Training model 558/1000
#   - Training model 559/1000
#   - Training model 560/1000
#   - Training model 561/1000
#   - Training model 562/1000
#   - Training model 563/1000
#   - Training model 564/1000
#   - Training model 565/1000
#   - Training model 566/1000
#   - Training model 567/1000
#   - Training model 568/1000
#   - Training model 569/1000
#   - Training model 570/1000
#   - Training model 571/1000
#   - Training model 572/1000
#   - Training model 573/1000
#   - Training model 574/1000
#   - Training model 575/1000
#   - Training model 576/1000
#   - Training model 577/1000
#   - Training model 578/1000
#   - Training model 579/1000
#   - Training model 580/1000
#   - Training model 581/1000
#   - Training model 582/1000
#   - Training model 583/1000
#   - Training model 584/1000
#   - Training model 585/1000
#   - Training model 586/1000
#   - Training model 587/1000
#   - Training model 588/1000
#   - Training model 589/1000
#   - Training model 590/1000
#   - Training model 591/1000
#   - Training model 592/1000
#   - Training model 593/1000
#   - Training model 594/1000
#   - Training model 595/1000
#   - Training model 596/1000
#   - Training model 597/1000
#   - Training model 598/1000
#   - Training model 599/1000
#   - Training model 600/1000
#   - Training model 601/1000
#   - Training model 602/1000
#   - Training model 603/1000
#   - Training model 604/1000
#   - Training model 605/1000
#   - Training model 606/1000
#   - Training model 607/1000
#   - Training model 608/1000
#   - Training model 609/1000
#   - Training model 610/1000
#   - Training model 611/1000
#   - Training model 612/1000
#   - Training model 613/1000
#   - Training model 614/1000
#   - Training model 615/1000
#   - Training model 616/1000
#   - Training model 617/1000
#   - Training model 618/1000
#   - Training model 619/1000
#   - Training model 620/1000
#   - Training model 621/1000
#   - Training model 622/1000
#   - Training model 623/1000
#   - Training model 624/1000
#   - Training model 625/1000
#   - Training model 626/1000
#   - Training model 627/1000
#   - Training model 628/1000
#   - Training model 629/1000
#   - Training model 630/1000
#   - Training model 631/1000
#   - Training model 632/1000
#   - Training model 633/1000
#   - Training model 634/1000
#   - Training model 635/1000
#   - Training model 636/1000
#   - Training model 637/1000
#   - Training model 638/1000
#   - Training model 639/1000
#   - Training model 640/1000
#   - Training model 641/1000
#   - Training model 642/1000
#   - Training model 643/1000
#   - Training model 644/1000
#   - Training model 645/1000
#   - Training model 646/1000
#   - Training model 647/1000
#   - Training model 648/1000
#   - Training model 649/1000
#   - Training model 650/1000
#   - Training model 651/1000
#   - Training model 652/1000
#   - Training model 653/1000
#   - Training model 654/1000
#   - Training model 655/1000
#   - Training model 656/1000
#   - Training model 657/1000
#   - Training model 658/1000
#   - Training model 659/1000
#   - Training model 660/1000
#   - Training model 661/1000
#   - Training model 662/1000
#   - Training model 663/1000
#   - Training model 664/1000
#   - Training model 665/1000
#   - Training model 666/1000
#   - Training model 667/1000
#   - Training model 668/1000
#   - Training model 669/1000
#   - Training model 670/1000
#   - Training model 671/1000
#   - Training model 672/1000
#   - Training model 673/1000
#   - Training model 674/1000
#   - Training model 675/1000
#   - Training model 676/1000
#   - Training model 677/1000
#   - Training model 678/1000
#   - Training model 679/1000
#   - Training model 680/1000
#   - Training model 681/1000
#   - Training model 682/1000
#   - Training model 683/1000
#   - Training model 684/1000
#   - Training model 685/1000
#   - Training model 686/1000
#   - Training model 687/1000
#   - Training model 688/1000
#   - Training model 689/1000
#   - Training model 690/1000
#   - Training model 691/1000
#   - Training model 692/1000
#   - Training model 693/1000
#   - Training model 694/1000
#   - Training model 695/1000
#   - Training model 696/1000
#   - Training model 697/1000
#   - Training model 698/1000
#   - Training model 699/1000
#   - Training model 700/1000
#   - Training model 701/1000
#   - Training model 702/1000
#   - Training model 703/1000
#   - Training model 704/1000
#   - Training model 705/1000
#   - Training model 706/1000
#   - Training model 707/1000
#   - Training model 708/1000
#   - Training model 709/1000
#   - Training model 710/1000
#   - Training model 711/1000
#   - Training model 712/1000
#   - Training model 713/1000
#   - Training model 714/1000
#   - Training model 715/1000
#   - Training model 716/1000
#   - Training model 717/1000
#   - Training model 718/1000
#   - Training model 719/1000
#   - Training model 720/1000
#   - Training model 721/1000
#   - Training model 722/1000
#   - Training model 723/1000
#   - Training model 724/1000
#   - Training model 725/1000
#   - Training model 726/1000
#   - Training model 727/1000
#   - Training model 728/1000
#   - Training model 729/1000
#   - Training model 730/1000
#   - Training model 731/1000
#   - Training model 732/1000
#   - Training model 733/1000
#   - Training model 734/1000
#   - Training model 735/1000
#   - Training model 736/1000
#   - Training model 737/1000
#   - Training model 738/1000
#   - Training model 739/1000
#   - Training model 740/1000
#   - Training model 741/1000
#   - Training model 742/1000
#   - Training model 743/1000
#   - Training model 744/1000
#   - Training model 745/1000
#   - Training model 746/1000
#   - Training model 747/1000
#   - Training model 748/1000
#   - Training model 749/1000
#   - Training model 750/1000
#   - Training model 751/1000
#   - Training model 752/1000
#   - Training model 753/1000
#   - Training model 754/1000
#   - Training model 755/1000
#   - Training model 756/1000
#   - Training model 757/1000
#   - Training model 758/1000
#   - Training model 759/1000
#   - Training model 760/1000
#   - Training model 761/1000
#   - Training model 762/1000
#   - Training model 763/1000
#   - Training model 764/1000
#   - Training model 765/1000
#   - Training model 766/1000
#   - Training model 767/1000
#   - Training model 768/1000
#   - Training model 769/1000
#   - Training model 770/1000
#   - Training model 771/1000
#   - Training model 772/1000
#   - Training model 773/1000
#   - Training model 774/1000
#   - Training model 775/1000
#   - Training model 776/1000
#   - Training model 777/1000
#   - Training model 778/1000
#   - Training model 779/1000
#   - Training model 780/1000
#   - Training model 781/1000
#   - Training model 782/1000
#   - Training model 783/1000
#   - Training model 784/1000
#   - Training model 785/1000
#   - Training model 786/1000
#   - Training model 787/1000
#   - Training model 788/1000
#   - Training model 789/1000
#   - Training model 790/1000
#   - Training model 791/1000
#   - Training model 792/1000
#   - Training model 793/1000
#   - Training model 794/1000
#   - Training model 795/1000
#   - Training model 796/1000
#   - Training model 797/1000
#   - Training model 798/1000
#   - Training model 799/1000
#   - Training model 800/1000
#   - Training model 801/1000
#   - Training model 802/1000
#   - Training model 803/1000
#   - Training model 804/1000
#   - Training model 805/1000
#   - Training model 806/1000
#   - Training model 807/1000
#   - Training model 808/1000
#   - Training model 809/1000
#   - Training model 810/1000
#   - Training model 811/1000
#   - Training model 812/1000
#   - Training model 813/1000
#   - Training model 814/1000
#   - Training model 815/1000
#   - Training model 816/1000
#   - Training model 817/1000
#   - Training model 818/1000
#   - Training model 819/1000
#   - Training model 820/1000
#   - Training model 821/1000
#   - Training model 822/1000
#   - Training model 823/1000
#   - Training model 824/1000
#   - Training model 825/1000
#   - Training model 826/1000
#   - Training model 827/1000
#   - Training model 828/1000
#   - Training model 829/1000
#   - Training model 830/1000
#   - Training model 831/1000
#   - Training model 832/1000
#   - Training model 833/1000
#   - Training model 834/1000
#   - Training model 835/1000
#   - Training model 836/1000
#   - Training model 837/1000
#   - Training model 838/1000
#   - Training model 839/1000
#   - Training model 840/1000
#   - Training model 841/1000
#   - Training model 842/1000
#   - Training model 843/1000
#   - Training model 844/1000
#   - Training model 845/1000
#   - Training model 846/1000
#   - Training model 847/1000
#   - Training model 848/1000
#   - Training model 849/1000
#   - Training model 850/1000
#   - Training model 851/1000
#   - Training model 852/1000
#   - Training model 853/1000
#   - Training model 854/1000
#   - Training model 855/1000
#   - Training model 856/1000
#   - Training model 857/1000
#   - Training model 858/1000
#   - Training model 859/1000
#   - Training model 860/1000
#   - Training model 861/1000
#   - Training model 862/1000
#   - Training model 863/1000
#   - Training model 864/1000
#   - Training model 865/1000
#   - Training model 866/1000
#   - Training model 867/1000
#   - Training model 868/1000
#   - Training model 869/1000
#   - Training model 870/1000
#   - Training model 871/1000
#   - Training model 872/1000
#   - Training model 873/1000
#   - Training model 874/1000
#   - Training model 875/1000
#   - Training model 876/1000
#   - Training model 877/1000
#   - Training model 878/1000
#   - Training model 879/1000
#   - Training model 880/1000
#   - Training model 881/1000
#   - Training model 882/1000
#   - Training model 883/1000
#   - Training model 884/1000
#   - Training model 885/1000
#   - Training model 886/1000
#   - Training model 887/1000
#   - Training model 888/1000
#   - Training model 889/1000
#   - Training model 890/1000
#   - Training model 891/1000
#   - Training model 892/1000
#   - Training model 893/1000
#   - Training model 894/1000
#   - Training model 895/1000
#   - Training model 896/1000
#   - Training model 897/1000
#   - Training model 898/1000
#   - Training model 899/1000
#   - Training model 900/1000
#   - Training model 901/1000
#   - Training model 902/1000
#   - Training model 903/1000
#   - Training model 904/1000
#   - Training model 905/1000
#   - Training model 906/1000
#   - Training model 907/1000
#   - Training model 908/1000
#   - Training model 909/1000
#   - Training model 910/1000
#   - Training model 911/1000
#   - Training model 912/1000
#   - Training model 913/1000
#   - Training model 914/1000
#   - Training model 915/1000
#   - Training model 916/1000
#   - Training model 917/1000
#   - Training model 918/1000
#   - Training model 919/1000
#   - Training model 920/1000
#   - Training model 921/1000
#   - Training model 922/1000
#   - Training model 923/1000
#   - Training model 924/1000
#   - Training model 925/1000
#   - Training model 926/1000
#   - Training model 927/1000
#   - Training model 928/1000
#   - Training model 929/1000
#   - Training model 930/1000
#   - Training model 931/1000
#   - Training model 932/1000
#   - Training model 933/1000
#   - Training model 934/1000
#   - Training model 935/1000
#   - Training model 936/1000
#   - Training model 937/1000
#   - Training model 938/1000
#   - Training model 939/1000
#   - Training model 940/1000
#   - Training model 941/1000
#   - Training model 942/1000
#   - Training model 943/1000
#   - Training model 944/1000
#   - Training model 945/1000
#   - Training model 946/1000
#   - Training model 947/1000
#   - Training model 948/1000
#   - Training model 949/1000
#   - Training model 950/1000
#   - Training model 951/1000
#   - Training model 952/1000
#   - Training model 953/1000
#   - Training model 954/1000
#   - Training model 955/1000
#   - Training model 956/1000
#   - Training model 957/1000
#   - Training model 958/1000
#   - Training model 959/1000
#   - Training model 960/1000
#   - Training model 961/1000
#   - Training model 962/1000
#   - Training model 963/1000
#   - Training model 964/1000
#   - Training model 965/1000
#   - Training model 966/1000
#   - Training model 967/1000
#   - Training model 968/1000
#   - Training model 969/1000
#   - Training model 970/1000
#   - Training model 971/1000
#   - Training model 972/1000
#   - Training model 973/1000
#   - Training model 974/1000
#   - Training model 975/1000
#   - Training model 976/1000
#   - Training model 977/1000
#   - Training model 978/1000
#   - Training model 979/1000
#   - Training model 980/1000
#   - Training model 981/1000
#   - Training model 982/1000
#   - Training model 983/1000
#   - Training model 984/1000
#   - Training model 985/1000
#   - Training model 986/1000
#   - Training model 987/1000
#   - Training model 988/1000
#   - Training model 989/1000
#   - Training model 990/1000
#   - Training model 991/1000
#   - Training model 992/1000
#   - Training model 993/1000
#   - Training model 994/1000
#   - Training model 995/1000
#   - Training model 996/1000
#   - Training model 997/1000
#   - Training model 998/1000
#   - Training model 999/1000
#   - Training model 1000/1000
#   🎉 New best model with accuracy: 0.0565
#   ✅ Best Acc This Gen: 0.0565 | Worst: 0.0033
#
# 🌱 Generation 2 | Population size: 600
#   - Training model 1/600
#   - Training model 2/600
#   - Training model 3/600
#   - Training model 4/600
#   - Training model 5/600
#   - Training model 6/600
#   - Training model 7/600
#   - Training model 8/600
#   - Training model 9/600
#   - Training model 10/600
#   - Training model 11/600
#   - Training model 12/600
#   - Training model 13/600
#   - Training model 14/600
#   - Training model 15/600
#   - Training model 16/600
#   - Training model 17/600
#   - Training model 18/600
#   - Training model 19/600
#   - Training model 20/600
#   - Training model 21/600
#   - Training model 22/600
#   - Training model 23/600
#   - Training model 24/600
#   - Training model 25/600
#   - Training model 26/600
#   - Training model 27/600
#   - Training model 28/600
#   - Training model 29/600
#   - Training model 30/600
#   - Training model 31/600
#   - Training model 32/600
#   - Training model 33/600
#   - Training model 34/600
#   - Training model 589/600
#   - Training model 590/600
#   - Training model 591/600
#   - Training model 592/600
#   - Training model 593/600
#   - Training model 594/600
#   - Training model 595/600
#   - Training model 596/600
#   - Training model 597/600
#   - Training model 598/600
#   - Training model 599/600
#   - Training model 600/600
#   🎉 New best model with accuracy: 0.0731
#   ✅ Best Acc This Gen: 0.0731 | Worst: 0.0066
#
# 🌱 Generation 3 | Population size: 360
#   - Training model 1/360
#   - Training model 2/360
#   - Training model 3/360
#   - Training model 4/360
#   - Training model 5/360
#   - Training model 6/360
#   - Training model 7/360
#   - Training model 8/360
#   - Training model 9/360
#   - Training model 10/360
#   - Training model 11/360
#   - Training model 12/360
#   - Training model 13/360
#   - Training model 14/360
#   - Training model 15/360
#   - Training model 16/360
#   - Training model 17/360
#   - Training model 18/360
#   - Training model 19/360
#   - Training model 20/360
#   - Training model 21/360
#   - Training model 22/360
#   - Training model 23/360
#   - Training model 24/360
#   - Training model 25/360
#   - Training model 26/360
#   - Training model 27/360
#   - Training model 28/360
#   - Training model 29/360
#   - Training model 30/360
#   - Training model 31/360
#   - Training model 32/360
#   - Training model 33/360
#   - Training model 34/360
#   - Training model 35/360
#   - Training model 36/360
#   - Training model 37/360
#   - Training model 38/360
#   - Training model 39/360
#   - Training model 40/360
#   - Training model 41/360
#   - Training model 42/360
#   - Training model 43/360
#   - Training model 44/360
#   - Training model 45/360
#   - Training model 46/360
#   - Training model 47/360
#   - Training model 48/360
#   - Training model 49/360
#   - Training model 50/360
#   - Training model 51/360
#   - Training model 52/360
#   - Training model 53/360
#   - Training model 54/360
#   - Training model 55/360
#   - Training model 56/360
#   - Training model 57/360
#   - Training model 58/360
#   - Training model 59/360
#   - Training model 60/360
#   - Training model 61/360
#   - Training model 62/360
#   - Training model 63/360
#   - Training model 64/360
#   - Training model 65/360
#   - Training model 66/360
#   - Training model 67/360
#   - Training model 68/360
#   - Training model 69/360
#   - Training model 70/360
#   - Training model 71/360
#   - Training model 72/360
#   - Training model 73/360
#   - Training model 74/360
#   - Training model 75/360
#   - Training model 76/360
#   - Training model 77/360
#   - Training model 78/360
#   - Training model 79/360
#   - Training model 80/360
#   - Training model 81/360
#   - Training model 82/360
#   - Training model 83/360
#   - Training model 84/360
#   - Training model 85/360
#   - Training model 86/360
#   - Training model 87/360
#   - Training model 88/360
#   - Training model 89/360
#   - Training model 90/360
#   - Training model 91/360
#   - Training model 92/360
#   - Training model 93/360
#   - Training model 94/360
#   - Training model 95/360
#   - Training model 96/360
#   - Training model 97/360
#   - Training model 98/360
#   - Training model 99/360
#   - Training model 100/360
#   - Training model 101/360
#   - Training model 102/360
#   - Training model 103/360
#   - Training model 104/360
#   - Training model 105/360
#   - Training model 106/360
#   - Training model 107/360
#   - Training model 108/360
#   - Training model 109/360
#   - Training model 110/360
#   - Training model 111/360
#   - Training model 112/360
#   - Training model 113/360
#   - Training model 114/360
#   - Training model 115/360
#   - Training model 116/360
#   - Training model 117/360
#   - Training model 118/360
#   - Training model 119/360
#   - Training model 120/360
#   - Training model 121/360
#   - Training model 122/360
#   - Training model 123/360
#   - Training model 124/360
#   - Training model 125/360
#   - Training model 126/360
#   - Training model 127/360
#   - Training model 128/360
#   - Training model 129/360
#   - Training model 130/360
#   - Training model 131/360
#   - Training model 132/360
#   - Training model 133/360
#   - Training model 134/360
#   - Training model 135/360
#   - Training model 136/360
#   - Training model 137/360
#   - Training model 138/360
#   - Training model 139/360
#   - Training model 140/360
#   - Training model 141/360
# ...
#   - Training model 321/360
#   - Training model 322/360
#   - Training model 323/360
#   - Training model 324/360
#   - Training model 325/360
#   - Training model 326/360
#   - Training model 327/360
#   - Training model 328/360
#   - Training model 329/360
#   - Training model 330/360
#   - Training model 331/360
#   - Training model 332/360
#   - Training model 333/360
#   - Training model 334/360
#   - Training model 335/360
#   - Training model 336/360
#   - Training model 337/360
#   - Training model 338/360
#   - Training model 339/360
#   - Training model 340/360
#   - Training model 341/360
#   - Training model 342/360
#   - Training model 343/360
#   - Training model 344/360
#   - Training model 345/360
#   - Training model 346/360
#   - Training model 347/360
#   - Training model 348/360
#   - Training model 349/360
#   - Training model 350/360
#   - Training model 351/360
#   - Training model 352/360
#   - Training model 353/360
#   - Training model 354/360
#   - Training model 355/360
#   - Training model 356/360
#   - Training model 357/360
#   - Training model 358/360
#   - Training model 359/360
#   - Training model 360/360
#   🎉 New best model with accuracy: 0.1030
#   ✅ Best Acc This Gen: 0.1030 | Worst: 0.0166
#
# 🌱 Generation 4 | Population size: 216
#   - Training model 1/216
#   - Training model 2/216
#   - Training model 3/216
#   - Training model 4/216
#   - Training model 5/216
#   - Training model 6/216
#   - Training model 7/216
#   - Training model 8/216
#   - Training model 9/216
#   - Training model 10/216
#   - Training model 11/216
#   - Training model 12/216
#   - Training model 13/216
#   - Training model 14/216
#   - Training model 15/216
#   - Training model 16/216
#   - Training model 17/216
#   - Training model 18/216
#   - Training model 19/216
#   - Training model 20/216
#   - Training model 21/216
#   - Training model 22/216
#   - Training model 23/216
#   - Training model 24/216
#   - Training model 25/216
#   - Training model 26/216
#   - Training model 27/216
#   - Training model 28/216
#   - Training model 29/216
#   - Training model 30/216
#   - Training model 31/216
#   - Training model 32/216
#   - Training model 33/216
#   - Training model 34/216
#   - Training model 35/216
#   - Training model 36/216
#   - Training model 37/216
#   - Training model 38/216
#   - Training model 39/216
#   - Training model 40/216
#   - Training model 41/216
#   - Training model 42/216
#   - Training model 43/216
#   - Training model 44/216
#   - Training model 45/216
#   - Training model 46/216
#   - Training model 47/216
#   - Training model 48/216
#   - Training model 49/216
#   - Training model 50/216
#   - Training model 51/216
#   - Training model 52/216
#   - Training model 53/216
#   - Training model 54/216
#   - Training model 55/216
#   - Training model 56/216
#   - Training model 57/216
#   - Training model 58/216
#   - Training model 59/216
#   - Training model 60/216
#   - Training model 61/216
#   - Training model 62/216
#   - Training model 63/216
#   - Training model 64/216
#   - Training model 65/216
#   - Training model 66/216
#   - Training model 67/216
#   - Training model 68/216
#   - Training model 69/216
#   - Training model 70/216
#   - Training model 125/129
#   - Training model 126/129
#   - Training model 127/129
#   - Training model 128/129
#   - Training model 129/129
#   🎉 New best model with accuracy: 0.1694
#   ✅ Best Acc This Gen: 0.1694 | Worst: 0.0399
#
# 🌱 Generation 6 | Population size: 77
#   - Training model 1/77
#   - Training model 2/77
#   - Training model 3/77
#   - Training model 4/77
#   - Training model 5/77
#   - Training model 6/77
#   - Training model 7/77
#   - Training model 8/77
#   - Training model 9/77
#   - Training model 10/77
#   - Training model 11/77
#   - Training model 12/77
#   - Training model 13/77
#   - Training model 14/77
#   - Training model 15/77
#   - Training model 16/77
#   - Training model 17/77
#   - Training model 18/77
#   - Training model 19/77
#   - Training model 20/77
#   - Training model 21/77
#   - Training model 22/77
#   - Training model 23/77
#   - Training model 24/77
#   - Training model 25/77
#   - Training model 26/77
#   - Training model 27/77
#   - Training model 28/77
#   - Training model 29/77
#   - Training model 30/77
#   - Training model 31/77
#   - Training model 32/77
#   - Training model 33/77
#   - Training model 34/77
#   - Training model 35/77
#   - Training model 36/77
#   - Training model 37/77
#   - Training model 38/77
#   - Training model 39/77
#   - Training model 40/77
#   - Training model 41/77
#   - Training model 42/77
#   - Training model 43/77
#   - Training model 44/77
#   - Training model 45/77
#   - Training model 46/77
#   - Training model 47/77
#   - Training model 48/77
#   - Training model 49/77
#   - Training model 50/77
#   - Training model 51/77
#   - Training model 52/77
#   - Training model 53/77
#   - Training model 54/77
#   - Training model 55/77
#   - Training model 56/77
#   - Training model 57/77
#   - Training model 58/77
#   - Training model 59/77
#   - Training model 60/77
#   - Training model 61/77
#   - Training model 62/77
#   - Training model 63/77
#   - Training model 64/77
#   - Training model 65/77
#   - Training model 66/77
#   - Training model 67/77
#   - Training model 68/77
#   - Training model 69/77
#   - Training model 70/77
#   - Training model 71/77
#   - Training model 72/77
#   - Training model 73/77
#   - Training model 74/77
#   - Training model 75/77
#   - Training model 76/77
#   - Training model 77/77
#   ✅ Best Acc This Gen: 0.1561 | Worst: 0.0698
#
# 🌱 Generation 7 | Population size: 46
#   - Training model 1/46
#   - Training model 2/46
#   - Training model 3/46
#   - Training model 4/46
#   - Training model 5/46
#   - Training model 6/46
#   - Training model 7/46
#   - Training model 8/46
#   - Training model 9/46
#   - Training model 10/46
#   - Training model 11/46
#   - Training model 12/46
#   - Training model 13/46
#   - Training model 14/46
#   - Training model 15/46
#   - Training model 16/46
#   - Training model 17/46
#   - Training model 18/46
#   - Training model 19/46
#   - Training model 20/46
#   - Training model 21/46
#   - Training model 22/46
#   - Training model 23/46
#   - Training model 24/46
#   - Training model 25/46
#   - Training model 26/46
#   - Training model 27/46
#   - Training model 28/46
#   - Training model 29/46
#   - Training model 30/46
#   - Training model 31/46
#   - Training model 32/46
#   - Training model 33/46
#   - Training model 34/46
#   - Training model 35/46
#   - Training model 36/46
#   - Training model 37/46
#   - Training model 38/46
#   - Training model 39/46
#   - Training model 40/46
#   - Training model 41/46
#   - Training model 42/46
#   - Training model 43/46
#   - Training model 44/46
#   - Training model 45/46
#   - Training model 46/46
#   ✅ Best Acc This Gen: 0.1694 | Worst: 0.0532
#
# 🌱 Generation 8 | Population size: 27
#   - Training model 1/27
#   - Training model 2/27
#   - Training model 3/27
#   - Training model 4/27
#   - Training model 5/27
#   - Training model 6/27
#   - Training model 7/27
#   - Training model 8/27
#   - Training model 9/27
#   - Training model 10/27
#   - Training model 11/27
#   - Training model 12/27
#   - Training model 13/27
#   - Training model 14/27
#   - Training model 15/27
#   - Training model 16/27
#   - Training model 17/27
#   - Training model 18/27
#   - Training model 19/27
#   - Training model 20/27
#   - Training model 21/27
#   - Training model 22/27
#   - Training model 23/27
#   - Training model 24/27
#   - Training model 25/27
#   - Training model 26/27
#   - Training model 27/27
#   🎉 New best model with accuracy: 0.1794
#   ✅ Best Acc This Gen: 0.1794 | Worst: 0.0997
#
# 🌱 Generation 9 | Population size: 16
#   - Training model 1/16
#   - Training model 2/16
#   - Training model 3/16
#   - Training model 4/16
#   - Training model 5/16
#   - Training model 6/16
#   - Training model 7/16
#   - Training model 8/16
#   - Training model 9/16
#   - Training model 10/16
#   - Training model 11/16
#   - Training model 12/16
#   - Training model 13/16
#   - Training model 14/16
#   - Training model 15/16
#   - Training model 16/16
#   🎉 New best model with accuracy: 0.2027
#   ✅ Best Acc This Gen: 0.2027 | Worst: 0.1262
#
# 🌱 Generation 10 | Population size: 9
#   - Training model 1/9
#   - Training model 2/9
#   - Training model 3/9
#   - Training model 4/9
#   - Training model 5/9
#   - Training model 6/9
#   - Training model 7/9
#   - Training model 8/9
#   - Training model 9/9
#   🎉 New best model with accuracy: 0.2093
#   ✅ Best Acc This Gen: 0.2093 | Worst: 0.1329
#
# 🌱 Generation 11 | Population size: 5
#   - Training model 1/5
#   - Training model 2/5
#   - Training model 3/5
#   - Training model 4/5
#   - Training model 5/5
#   ✅ Best Acc This Gen: 0.2060 | Worst: 0.1761
#
# 🌱 Generation 12 | Population size: 3
#   - Training model 1/3
#   - Training model 2/3
#   - Training model 3/3
#   🔄 Best model preserved with elitism
#   ✅ Best Acc This Gen: 0.1993 | Worst: 0.1860
#
# 🌱 Generation 13 | Population size: 2
#   - Training model 1/2
#   - Training model 2/2
#   🎉 New best model with accuracy: 0.2159
#   ✅ Best Acc This Gen: 0.2159 | Worst: 0.2060
#
# 🎯 Final test accuracy on Omniglot: 23.00%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import Omniglot
import torchvision.transforms as transforms
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import accuracy_score

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Resize transform: resize to 28x28 + ToTensor()
transform = transforms.Compose([
    transforms.Resize((28, 28)),  # Resize images to 28x28
    transforms.ToTensor(),        # Convert PIL image to tensor and scale to [0,1]
])

# Load Omniglot dataset (background=True for training, False for testing)
train_dataset = Omniglot(root='./data', background=True, download=True, transform=transform)
test_dataset = Omniglot(root='./data', background=False, download=True, transform=transform)

# Combine train and test for one dataset
full_data = train_dataset + test_dataset

# Extract data and labels into numpy arrays
X = []
y = []
for img, label in full_data:
    X.append(img.view(-1).numpy())  # flatten 28x28 -> 784
    y.append(label)

X = np.stack(X)
y = np.array(y)

# Limit to first 50 classes to keep problem manageable
max_classes = 50
mask = y < max_classes
X = X[mask]
y = y[mask]

# Encode labels 0..49
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Train/val/test split: 70% train, 15% val, 15% test
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y_encoded, test_size=0.15, random_state=42, stratify=y_encoded
)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.1765, random_state=42, stratify=y_trainval
)

# Convert to tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.long)
X_val_t = torch.tensor(X_val, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.long)
X_test_t = torch.tensor(X_test, dtype=torch.float32)
y_test_t = torch.tensor(y_test, dtype=torch.long)

# Create dataloaders
batch_size = 64
train_loader = DataLoader(torch.utils.data.TensorDataset(X_train_t, y_train_t), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(torch.utils.data.TensorDataset(X_val_t, y_val_t), batch_size=batch_size)
test_loader = DataLoader(torch.utils.data.TensorDataset(X_test_t, y_test_t), batch_size=batch_size)

# Define MLP model with input size 784 (28x28) and 50 classes
class OmniglotMLP(nn.Module):
    def __init__(self, input_size=28*28, num_classes=max_classes):
        super(OmniglotMLP, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# Evaluation function
def evaluate_model(model, dataloader):
    model.eval()
    all_preds = []
    all_targets = []
    with torch.no_grad():
        for xb, yb in dataloader:
            xb, yb = xb.to(device), yb.to(device)
            xb = xb.view(xb.size(0), -1)  # Flatten
            logits = model(xb)
            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu().numpy())
            all_targets.append(yb.cpu().numpy())
    all_preds = np.concatenate(all_preds)
    all_targets = np.concatenate(all_targets)
    acc = accuracy_score(all_targets, all_preds)
    return acc

# Training function for one epoch
def train_one_epoch(model, optimizer, criterion, dataloader):
    model.train()
    running_loss = 0
    for xb, yb in dataloader:
        xb, yb = xb.to(device), yb.to(device)
        xb = xb.view(xb.size(0), -1)  # Flatten
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * xb.size(0)
    return running_loss / len(dataloader.dataset)

# Instantiate model, loss, optimizer
model = OmniglotMLP().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Optional: Enable cudnn benchmark for performance if CUDA
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True

# Training loop
num_epochs = 150
for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, optimizer, criterion, train_loader)
    if (epoch + 1) % 5 == 0 or epoch == 0:
        val_acc = evaluate_model(model, val_loader)
        print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f} - Val Accuracy: {val_acc:.4f}")

# Final evaluation on test set
test_acc = evaluate_model(model, test_loader)
print(f"\nFinal Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/150 - Train Loss: 3.9461 - Val Accuracy: 0.0266
# Epoch 5/150 - Train Loss: 3.9162 - Val Accuracy: 0.0199
# Epoch 10/150 - Train Loss: 3.9137 - Val Accuracy: 0.0199
# Epoch 15/150 - Train Loss: 3.9105 - Val Accuracy: 0.0166
# Epoch 20/150 - Train Loss: 3.8874 - Val Accuracy: 0.0233
# Epoch 25/150 - Train Loss: 3.8297 - Val Accuracy: 0.0465
# Epoch 30/150 - Train Loss: 3.7909 - Val Accuracy: 0.0498
# Epoch 35/150 - Train Loss: 3.7763 - Val Accuracy: 0.0465
# Epoch 40/150 - Train Loss: 3.7469 - Val Accuracy: 0.0465
# Epoch 45/150 - Train Loss: 3.7436 - Val Accuracy: 0.0399
# Epoch 50/150 - Train Loss: 3.7301 - Val Accuracy: 0.0498
# Epoch 55/150 - Train Loss: 3.7450 - Val Accuracy: 0.0532
# Epoch 60/150 - Train Loss: 3.7190 - Val Accuracy: 0.0764
# Epoch 65/150 - Train Loss: 3.7264 - Val Accuracy: 0.0797
# Epoch 70/150 - Train Loss: 3.6988 - Val Accuracy: 0.0532
# Epoch 75/150 - Train Loss: 3.6832 - Val Accuracy: 0.0631
# Epoch 80/150 - Train Loss: 3.6974 - Val Accuracy: 0.0864
# Epoch 85/150 - Train Loss: 3.6649 - Val Accuracy: 0.0831
# Epoch 90/150 - Train Loss: 3.6922 - Val Accuracy: 0.0432
# Epoch 95/150 - Train Loss: 3.6604 - Val Accuracy: 0.0764
# Epoch 100/150 - Train Loss: 3.6393 - Val Accuracy: 0.0465
# Epoch 105/150 - Train Loss: 3.6478 - Val Accuracy: 0.0598
# Epoch 110/150 - Train Loss: 3.6343 - Val Accuracy: 0.0831
# Epoch 115/150 - Train Loss: 3.6200 - Val Accuracy: 0.0764
# Epoch 120/150 - Train Loss: 3.6353 - Val Accuracy: 0.0731
# Epoch 125/150 - Train Loss: 3.6414 - Val Accuracy: 0.0731
# Epoch 130/150 - Train Loss: 3.6285 - Val Accuracy: 0.0731
# Epoch 135/150 - Train Loss: 3.6199 - Val Accuracy: 0.0598
# Epoch 140/150 - Train Loss: 3.6526 - Val Accuracy: 0.0332
# Epoch 145/150 - Train Loss: 3.6273 - Val Accuracy: 0.0532
# Epoch 150/150 - Train Loss: 3.5919 - Val Accuracy: 0.0731
#
# Final Test Accuracy: 0.0667

# %%
import math

def generations_to_one(pop_size, survival_rate):
    # Calculate how many generations until population shrinks to 1 or less
    return 1 + math.ceil(math.log(1 / pop_size) / math.log(survival_rate))

def total_epochs_final_model(pop_size, survival_rate, epochs_per_gen):
    G = generations_to_one(pop_size, survival_rate)
    total = G * epochs_per_gen
    return total, G

# Example usage:
pop_size = 1000
survival_rate = 0.6
epochs_per_gen = 10  # for example


total, generations = total_epochs_final_model(pop_size, survival_rate, epochs_per_gen)
print(f"Generations: {generations}, Total epochs for final model: {total}")
# Out:
# Generations: 15, Total epochs for final model: 150
